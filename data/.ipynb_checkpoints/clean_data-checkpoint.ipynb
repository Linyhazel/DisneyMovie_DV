# %% [markdown]
# # Exploratory Data Analysis and Data Clean Up

# %% [markdown]
# The main goal of this notebook is to get a global view of the four dataset we found. In order to get as much useful information as possible, we will then merge the four dataset and get one clean data. In the later work, the clean dataset will be the only dataset we use.

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %% [markdown]
# ## Explore the first dataset

# %%
# data1 comes from https://www.kaggle.com/sooaaib/walt-disney-movies?select=disney_movies.csv
# read data1
data1 = pd.read_csv('./data1.csv', error_bad_lines=False)
print('size of the first dataset is ', data1.shape)
data1.head()
# Out:
# size of the first dataset is  (437, 36)
#    Unnamed: 0                            title       Production company  \
# 0           0          Academy Award Review of  Walt Disney Productions
# 1           1  Snow White and the Seven Dwarfs  Walt Disney Productions
# 2           2                        Pinocchio  Walt Disney Productions
# 3           3                         Fantasia  Walt Disney Productions
# 4           4             The Reluctant Dragon  Walt Disney Productions
#
#                                         Release date  \
# 0                                   ['May 19, 1937']
# 1  ['December 21, 1937 ( Carthay Circle Theatre ,...
# 2  ['February 7, 1940 ( Center Theatre )', 'Febru...
# 3                              ['November 13, 1940']
# 4                                  ['June 20, 1941']
#
#                            Running time        Country Language  \
# 0  41 minutes (74 minutes 1966 release)  United States  English
# 1                            83 minutes  United States  English
# 2                            88 minutes  United States  English
# 3                           126 minutes  United States  English
# 4                            74 minutes  United States  English
#
#                      Box office  Running time (int)  Budget (float)  ...  \
# 0                       $45.472                41.0             NaN  ...
# 1                  $418 million                83.0       1490000.0  ...
# 2                  $164 million                88.0       2600000.0  ...
# 3           $76.4–$83.3 million               126.0       2280000.0  ...
# 4  $960,000 (worldwide rentals)                74.0        600000.0  ...
#
#     Narrated by   Cinematography        Edited by Screenplay by  \
# 0           NaN              NaN              NaN           NaN
# 1           NaN              NaN              NaN           NaN
# 2           NaN              NaN              NaN           NaN
# 3  Deems Taylor  James Wong Howe              NaN           NaN
# 4           NaN     Bert Giennon  Paul Weatherwax           NaN
#
#   Production companies  Japanese Hepburn Adaptation by Traditional Simplified
# 0                  NaN       NaN     NaN           NaN         NaN        NaN
# 1                  NaN       NaN     NaN           NaN         NaN        NaN
# 2                  NaN       NaN     NaN           NaN         NaN        NaN
# 3                  NaN       NaN     NaN           NaN         NaN        NaN
# 4                  NaN       NaN     NaN           NaN         NaN        NaN
#
# [5 rows x 36 columns]

# %%
print("Number of unique films: ", len(data1.title.unique()))
print("Number of unique release date: ", len(data1['Release date'].unique()))
# Out:
# Number of unique films:  424
# Number of unique release date:  433

# %% [markdown]
# Among the 437 films, unique films take up 424, but the unique number of release date is different. Therefore, we deduce that there may be films that are remade.

# %%
data1['title'].value_counts()
# Out:
# Freaky Friday            2
# Cinderella               2
# The Parent Trap          2
# Mulan                    2
# Pete's Dragon            2
#                         ..
# The Haunted Mansion      1
# Artemis Fowl             1
# Cars 2                   1
# Pinocchio                1
# Planes: Fire & Rescue    1
# Name: title, Length: 424, dtype: int64

# %%
data1.loc[data1['title'] == 'Freaky Friday']
# Out:
#      Unnamed: 0          title                      Production company  \
# 127         127  Freaky Friday                 Walt Disney Productions
# 265         265  Freaky Friday  ['Walt Disney Pictures', 'Gunn Films']
#
#                                           Release date Running time  \
# 127                              ['December 17, 1976']   95 minutes
# 265  ['August 4, 2003 ( Los Angeles )', 'August 6, ...   97 minutes
#
#            Country Language      Box office  Running time (int)  \
# 127  United States  English     $36 million                95.0
# 265  United States  English  $160.8 million                97.0
#
#      Budget (float)  ...  Narrated by      Cinematography         Edited by  \
# 127       5000000.0  ...          NaN  Charles F. Wheeler  Cotton Warburton
# 265      26000000.0  ...          NaN         Oliver Wood       Bruce Green
#
#                         Screenplay by Production companies  Japanese Hepburn  \
# 127                      Mary Rodgers                  NaN       NaN     NaN
# 265  ['Heather Hach', 'Leslie Dixon']                  NaN       NaN     NaN
#
#     Adaptation by Traditional Simplified
# 127           NaN         NaN        NaN
# 265           NaN         NaN        NaN
#
# [2 rows x 36 columns]

# %% [markdown]
# We first consider different versions of the same film as different ones. There are 36 features in total in data1, but we are interested in only part of those features, select the useful features.

# %%
list(data1.columns)
# Out:
# ['Unnamed: 0',
#  'title',
#  'Production company',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Box office',
#  'Running time (int)',
#  'Budget (float)',
#  'Box office (float)',
#  'Release date (datetime)',
#  'imdb_rating',
#  'imdb_votes',
#  'imdb_id',
#  'metascore',
#  'rotten_tomatoes',
#  'Directed by',
#  'Produced by',
#  'Written by',
#  'Based on',
#  'Starring',
#  'Music by',
#  'Distributed by',
#  'Budget',
#  'Story by',
#  'Narrated by',
#  'Cinematography',
#  'Edited by',
#  'Screenplay by',
#  'Production companies',
#  'Japanese',
#  'Hepburn',
#  'Adaptation by',
#  'Traditional',
#  'Simplified']

# %%
# select the features are useful to our project
data1_select = data1[['title',
 'Running time (int)',
 'Budget (float)',
 'Box office (float)',
 'Release date (datetime)',
 'imdb_rating',
 'metascore',
 'rotten_tomatoes',
 'Directed by',
 'Produced by',
 'Music by',
 'Distributed by']].rename(columns={'Running time (int)': 'Running time', 
                                    'Budget (float)': 'Budget',
                                    'Box office (float)': 'Box office',
                                    'Release date (datetime)': 'Release date',
                                    'imdb_rating': 'imdb'})
data1_select
# Out:
#                                title  Running time       Budget    Box office  \
# 0            Academy Award Review of          41.0          NaN  4.547200e+01
# 1    Snow White and the Seven Dwarfs          83.0    1490000.0  4.180000e+08
# 2                          Pinocchio          88.0    2600000.0  1.640000e+08
# 3                           Fantasia         126.0    2280000.0  8.330000e+07
# 4               The Reluctant Dragon          74.0     600000.0  9.600000e+05
# ..                               ...           ...          ...           ...
# 432                             Soul         100.0  150000000.0           NaN
# 433         Raya and the Last Dragon           NaN          NaN           NaN
# 434                          Cruella           NaN          NaN           NaN
# 435                    Jungle Cruise           NaN          NaN           NaN
# 436            The Beatles: Get Back           NaN          NaN           NaN
#
#     Release date  imdb  metascore rotten_tomatoes  \
# 0     1937-05-19   7.2        7.2             NaN
# 1     1937-12-21   7.6        7.6             NaN
# 2     1940-02-07   7.4        7.4            100%
# 3     1940-11-13   7.8        7.8             95%
# 4     1941-06-20   6.9        6.9             67%
# ..           ...   ...        ...             ...
# 432   2020-10-11   7.0        7.0             45%
# 433   2021-03-12   NaN        NaN             NaN
# 434   2021-05-28   NaN        NaN             NaN
# 435   2021-07-30   NaN        NaN             NaN
# 436          NaN   8.0        8.0             NaN
#
#                                            Directed by  \
# 0                                                  NaN
# 1    ['David Hand (supervising)', 'William Cottrell...
# 2    ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 3    ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 4    ['Alfred Werker', '(live action)', 'Hamilton L...
# ..                                                 ...
# 432                                        Pete Docter
# 433               ['Don Hall', 'Carlos López Estrada']
# 434                                    Craig Gillespie
# 435                                 Jaume Collet-Serra
# 436                                      Peter Jackson
#
#                                            Produced by  \
# 0                                                  NaN
# 1                                          Walt Disney
# 2                                          Walt Disney
# 3                    ['Walt Disney', 'Ben Sharpsteen']
# 4                                          Walt Disney
# ..                                                 ...
# 432                                        Dana Murray
# 433                ['Osnat Shurer', 'Peter Del Vecho']
# 434      ['Kristin Burr', 'Andrew Gunn', 'Marc Platt']
# 435  ['John Davis', 'John Fox', 'Beau Flynn', 'Dway...
# 436  ['Peter Jackson', 'Clare Olssen', 'Jonathan Cl...
#
#                                               Music by  \
# 0                                                  NaN
# 1    ['Frank Churchill', 'Paul Smith', 'Leigh Harli...
# 2                   ['Leigh Harline', 'Paul J. Smith']
# 3                                          See program
# 4                   ['Frank Churchill', 'Larry Morey']
# ..                                                 ...
# 432                   ['Trent Reznor', 'Atticus Ross']
# 433                                                NaN
# 434                                                NaN
# 435               ['James Newton Howard', 'Metallica']
# 436                                        The Beatles
#
#                                         Distributed by
# 0                                                  NaN
# 1                                   RKO Radio Pictures
# 2                                   RKO Radio Pictures
# 3    ['Walt Disney Productions', 'RKO Radio Pictures']
# 4                                   RKO Radio Pictures
# ..                                                 ...
# 432         ['Walt Disney Studios', 'Motion Pictures']
# 433         ['Walt Disney Studios', 'Motion Pictures']
# 434                Walt Disney Studios Motion Pictures
# 435                Walt Disney Studios Motion Pictures
# 436         ['Walt Disney Studios', 'Motion Pictures']
#
# [437 rows x 12 columns]

# %% [markdown]
# ## Explore the second dataset

# %%
# read data2 from https://www.kaggle.com/dikshabhati2002/walt-disney-movies
data2 = pd.read_csv('./data2.csv', error_bad_lines=False)
print('size of the second dataset is ', data2.shape)
data2.head()
# Out:
# size of the second dataset is  (444, 21)
#    Unnamed: 0                            title       Production company  \
# 0           0          Academy Award Review of  Walt Disney Productions
# 1           1  Snow White and the Seven Dwarfs  Walt Disney Productions
# 2           2                        Pinocchio  Walt Disney Productions
# 3           3                         Fantasia  Walt Disney Productions
# 4           4             The Reluctant Dragon  Walt Disney Productions
#
#          Country Language  Running time     Budget    Box office Release date  \
# 0  United States  English          41.0        NaN  4.547200e+01   1937-05-19
# 1  United States  English          83.0  1490000.0  4.180000e+08   1937-12-21
# 2  United States  English          88.0  2600000.0  1.640000e+08   1940-02-07
# 3  United States  English         126.0  2280000.0  8.330000e+07   1940-11-13
# 4  United States  English          74.0   600000.0  9.600000e+05   1941-06-20
#
#    imdb  ...  rotten_tomatoes  \
# 0   7.2  ...              NaN
# 1   7.6  ...              NaN
# 2   7.4  ...              73%
# 3   7.7  ...              95%
# 4   6.9  ...              68%
#
#                                          Directed by  \
# 0                                                NaN
# 1  ['David Hand (supervising)', 'William Cottrell...
# 2  ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 3  ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 4  ['Alfred Werker', '(live action)', 'Hamilton L...
#
#                          Produced by  \
# 0                                NaN
# 1                        Walt Disney
# 2                        Walt Disney
# 3  ['Walt Disney', 'Ben Sharpsteen']
# 4                        Walt Disney
#
#                                             Based on  \
# 0                                                NaN
# 1         ['Snow White', 'by The', 'Brothers Grimm']
# 2  ['The Adventures of Pinocchio', 'by', 'Carlo C...
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  \
# 0                                                NaN
# 1  ['Adriana Caselotti', 'Lucille La Verne', 'Har...
# 2  ['Cliff Edwards', 'Dickie Jones', 'Christian R...
# 3              ['Leopold Stokowski', 'Deems Taylor']
# 4  ['Robert Benchley', 'Frances Gifford', 'Buddy ...
#
#                                             Music by      Distributed by  \
# 0                                                NaN                 NaN
# 1  ['Frank Churchill', 'Paul Smith', 'Leigh Harli...  RKO Radio Pictures
# 2                 ['Leigh Harline', 'Paul J. Smith']  RKO Radio Pictures
# 3                                        See program  RKO Radio Pictures
# 4                 ['Frank Churchill', 'Larry Morey']  RKO Radio Pictures
#
#     Cinematography        Edited by Screenplay by
# 0              NaN              NaN           NaN
# 1              NaN              NaN           NaN
# 2              NaN              NaN           NaN
# 3  James Wong Howe              NaN           NaN
# 4     Bert Giennon  Paul Weatherwax           NaN
#
# [5 rows x 21 columns]

# %%
print("Number of unique films: ", len(data2.title.unique()))
print("Number of unique release date: ", len(data2['Release date'].unique()))
data1['title'].value_counts()
# Out:
# Number of unique films:  431
# Number of unique release date:  430
# Freaky Friday            2
# Cinderella               2
# The Parent Trap          2
# Mulan                    2
# Pete's Dragon            2
#                         ..
# The Haunted Mansion      1
# Artemis Fowl             1
# Cars 2                   1
# Pinocchio                1
# Planes: Fire & Rescue    1
# Name: title, Length: 424, dtype: int64

# %%
data2.loc[data2['title'] == 'Freaky Friday']
# Out:
#      Unnamed: 0          title                      Production company  \
# 127         127  Freaky Friday                 Walt Disney Productions
# 265         265  Freaky Friday  ['Walt Disney Pictures', 'Gunn Films']
#
#            Country Language  Running time      Budget   Box office  \
# 127  United States  English          95.0   5000000.0   36000000.0
# 265  United States  English          97.0  26000000.0  160800000.0
#
#     Release date  imdb  ...  rotten_tomatoes  Directed by  Produced by  \
# 127   1976-12-20   6.2  ...              88%  Gary Nelson   Ron Miller
# 265   2003-08-04   6.2  ...              88%  Mark Waters  Andrew Gunn
#
#                                     Based on  \
# 127     ['Freaky Friday', 'by Mary Rodgers']
# 265  ['Freaky Friday', 'by', 'Mary Rodgers']
#
#                                               Starring       Music by  \
# 127   ['Jodie Foster', 'Barbara Harris', 'John Astin']  Johnny Mandel
# 265  ['Jamie Lee Curtis', 'Lindsay Lohan', 'Harold ...     Rolfe Kent
#
#                Distributed by      Cinematography         Edited by  \
# 127  Buena Vista Distribution  Charles F. Wheeler  Cotton Warburton
# 265      Buena Vista Pictures         Oliver Wood       Bruce Green
#
#                         Screenplay by
# 127                      Mary Rodgers
# 265  ['Heather Hach', 'Leslie Dixon']
#
# [2 rows x 21 columns]

# %%
list(data2.columns)
# Out:
# ['Unnamed: 0',
#  'title',
#  'Production company',
#  'Country',
#  'Language',
#  'Running time',
#  'Budget',
#  'Box office',
#  'Release date',
#  'imdb',
#  'metascore',
#  'rotten_tomatoes',
#  'Directed by',
#  'Produced by',
#  'Based on',
#  'Starring',
#  'Music by',
#  'Distributed by',
#  'Cinematography',
#  'Edited by',
#  'Screenplay by']

# %%
# select features
data2_select = data2[['title',
 'Running time',
 'Budget',
 'Box office',
 'Release date',
 'imdb',
 'metascore',
 'rotten_tomatoes',
 'Directed by',
 'Produced by',
 'Music by',
 'Distributed by']]
data2_select
# Out:
#                                title  Running time       Budget    Box office  \
# 0            Academy Award Review of          41.0          NaN  4.547200e+01
# 1    Snow White and the Seven Dwarfs          83.0    1490000.0  4.180000e+08
# 2                          Pinocchio          88.0    2600000.0  1.640000e+08
# 3                           Fantasia         126.0    2280000.0  8.330000e+07
# 4               The Reluctant Dragon          74.0     600000.0  9.600000e+05
# ..                               ...           ...          ...           ...
# 439               The Little Mermaid           NaN          NaN           NaN
# 440                Peter Pan & Wendy           NaN          NaN           NaN
# 441                       Home Alone           NaN          NaN           NaN
# 442                           Shrunk           NaN          NaN           NaN
# 443              Night at the Museum         306.0  387000000.0  1.310000e+09
#
#     Release date  imdb  metascore rotten_tomatoes  \
# 0     1937-05-19   7.2        NaN             NaN
# 1     1937-12-21   7.6       95.0             NaN
# 2     1940-02-07   7.4       99.0             73%
# 3     1940-11-13   7.7       96.0             95%
# 4     1941-06-20   6.9        NaN             68%
# ..           ...   ...        ...             ...
# 439          NaN   7.6       88.0             93%
# 440          NaN   NaN        NaN             NaN
# 441          NaN   7.6       63.0             66%
# 442          NaN   NaN        NaN             NaN
# 443          NaN   6.4       48.0             43%
#
#                                            Directed by  \
# 0                                                  NaN
# 1    ['David Hand (supervising)', 'William Cottrell...
# 2    ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 3    ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 4    ['Alfred Werker', '(live action)', 'Hamilton L...
# ..                                                 ...
# 439                                       Rob Marshall
# 440                                       David Lowery
# 441                                          Dan Mazer
# 442                                       Joe Johnston
# 443                                         Shawn Levy
#
#                                            Produced by  \
# 0                                                  NaN
# 1                                          Walt Disney
# 2                                          Walt Disney
# 3                    ['Walt Disney', 'Ben Sharpsteen']
# 4                                          Walt Disney
# ..                                                 ...
# 439  ['Rob Marshall', 'John DeLuca', 'Marc Platt', ...
# 440                       ['Jim Whitaker', 'Joe Roth']
# 441                     ['Hutch Parker', 'Dan Wilson']
# 442               ['David Hoberman', 'Todd Lieberman']
# 443  ['Shawn Levy', 'Chris Columbus', 'Michael Barn...
#
#                                               Music by  \
# 0                                                  NaN
# 1    ['Frank Churchill', 'Paul Smith', 'Leigh Harli...
# 2                   ['Leigh Harline', 'Paul J. Smith']
# 3                                          See program
# 4                   ['Frank Churchill', 'Larry Morey']
# ..                                                 ...
# 439  ['Alan Menken (score and songs)', 'Howard Ashm...
# 440                                                NaN
# 441                                        John Debney
# 442                                                NaN
# 443                                     Alan Silvestri
#
#                                  Distributed by
# 0                                           NaN
# 1                            RKO Radio Pictures
# 2                            RKO Radio Pictures
# 3                            RKO Radio Pictures
# 4                            RKO Radio Pictures
# ..                                          ...
# 439  ['Walt Disney Studios', 'Motion Pictures']
# 440         Walt Disney Studios Motion Pictures
# 441                                     Disney+
# 442  ['Walt Disney Studios', 'Motion Pictures']
# 443         ['20th Century Studios', 'Disney+']
#
# [444 rows x 12 columns]

# %% [markdown]
# ## Explore the third dataset

# %%
# read data3 from https://www.kaggle.com/prateekmaj21/disney-movies
data3 = pd.read_csv('./data3.csv', error_bad_lines=False)
print('size of the third dataset is ', data3.shape)
data3.head()
# Out:
# size of the third dataset is  (579, 6)
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross
# 0    184925485                5228953251
# 1     84300000                2188229052
# 2     83320000                2187090808
# 3     65000000                1078510579
# 4     85000000                 920608730

# %% [markdown]
# In this dataset, we are interested in the genre and the inflation adjusted gross.

# %%
data3_select = data3[['movie_title','release_date','genre','inflation_adjusted_gross']].rename(columns={'movie_title': 'title','release_date': 'Release date'})
data3_select
# Out:
#                                title Release date      genre  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical
# 1                          Pinocchio   1940-02-09  Adventure
# 2                           Fantasia   1940-11-13    Musical
# 3                  Song of the South   1946-11-12  Adventure
# 4                         Cinderella   1950-02-15      Drama
# ..                               ...          ...        ...
# 574         The Light Between Oceans   2016-09-02      Drama
# 575                   Queen of Katwe   2016-09-23      Drama
# 576                   Doctor Strange   2016-11-04  Adventure
# 577                            Moana   2016-11-23  Adventure
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure
#
#      inflation_adjusted_gross
# 0                  5228953251
# 1                  2188229052
# 2                  2187090808
# 3                  1078510579
# 4                   920608730
# ..                        ...
# 574                  12545979
# 575                   8874389
# 576                 232532923
# 577                 246082029
# 578                 529483936
#
# [579 rows x 4 columns]

# %% [markdown]
# ## Explore the fourth dataset

# %%
# read data4 from https://www.kaggle.com/therealsampat/disney-movies-dataset
data4 = pd.read_csv('./data4.csv', error_bad_lines=False)
print('size of the fourth dataset is ', data4.shape)
data4.head()
# Out:
# size of the fourth dataset is  (432, 32)
#    Unnamed: 0                            title       Production company  \
# 0           0          Academy Award Review of  Walt Disney Productions
# 1           1  Snow White and the Seven Dwarfs  Walt Disney Productions
# 2           2                        Pinocchio  Walt Disney Productions
# 3           3                         Fantasia  Walt Disney Productions
# 4           4             The Reluctant Dragon  Walt Disney Productions
#
#                                         Release date  \
# 0                                   ['May 19, 1937']
# 1  ['December 21, 1937 ( Carthay Circle Theatre ,...
# 2  ['February 7, 1940 ( Center Theatre )', 'Febru...
# 3                              ['November 13, 1940']
# 4                                  ['June 20, 1941']
#
#                            Running time        Country Language  \
# 0  41 minutes (74 minutes 1966 release)  United States  English
# 1                            83 minutes  United States  English
# 2                            88 minutes  United States  English
# 3                           126 minutes  United States  English
# 4                            74 minutes  United States  English
#
#    Running time (int)  Budget (float)  Box office (float)  ...  \
# 0                41.0             NaN                 NaN  ...
# 1                83.0       1490000.0         418000000.0  ...
# 2                88.0       2600000.0         164000000.0  ...
# 3               126.0       2280000.0          83300000.0  ...
# 4                74.0        600000.0            960000.0  ...
#
#                      Box office  \
# 0                           NaN
# 1                  $418 million
# 2                  $164 million
# 3           $76.4–$83.3 million
# 4  $960,000 (worldwide rentals)
#
#                                             Story by   Narrated by  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2  ['Ted Sears', 'Otto Englander', 'Webb Smith', ...           NaN
# 3                       ['Joe Grant', 'Dick Huemer']  Deems Taylor
# 4                                                NaN           NaN
#
#     Cinematography        Edited by Screenplay by Production companies  \
# 0              NaN              NaN           NaN                  NaN
# 1              NaN              NaN           NaN                  NaN
# 2              NaN              NaN           NaN                  NaN
# 3  James Wong Howe              NaN           NaN                  NaN
# 4     Bert Giennon  Paul Weatherwax           NaN                  NaN
#
#   Adaptation by Traditional Simplified
# 0           NaN         NaN        NaN
# 1           NaN         NaN        NaN
# 2           NaN         NaN        NaN
# 3           NaN         NaN        NaN
# 4           NaN         NaN        NaN
#
# [5 rows x 32 columns]

# %%
list(data4.columns)
# Out:
# ['Unnamed: 0',
#  'title',
#  'Production company',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Running time (int)',
#  'Budget (float)',
#  'Box office (float)',
#  'Release date (datetime)',
#  'imdb',
#  'metascore',
#  'rotten_tomatoes',
#  'Directed by',
#  'Produced by',
#  'Written by',
#  'Based on',
#  'Starring',
#  'Music by',
#  'Distributed by',
#  'Budget',
#  'Box office',
#  'Story by',
#  'Narrated by',
#  'Cinematography',
#  'Edited by',
#  'Screenplay by',
#  'Production companies',
#  'Adaptation by',
#  'Traditional',
#  'Simplified']

# %%
# select features
data4_select = data4[['title',
 'Running time (int)',
 'Budget (float)',
 'Box office (float)',
 'Release date (datetime)',
 'imdb',
 'metascore',
 'rotten_tomatoes',
 'Directed by',
 'Produced by',
 'Music by',
 'Distributed by',]].rename(columns={'Running time (int)': 'Running time', 
                                    'Budget (float)': 'Budget',
                                    'Box office (float)': 'Box office',
                                    'Release date (datetime)': 'Release date'})
data4_select
# Out:
#                                title  Running time       Budget   Box office  \
# 0            Academy Award Review of          41.0          NaN          NaN
# 1    Snow White and the Seven Dwarfs          83.0    1490000.0  418000000.0
# 2                          Pinocchio          88.0    2600000.0  164000000.0
# 3                           Fantasia         126.0    2280000.0   83300000.0
# 4               The Reluctant Dragon          74.0     600000.0     960000.0
# ..                               ...           ...          ...          ...
# 427                             Soul           NaN  150000000.0          NaN
# 428         Raya and the Last Dragon           NaN          NaN          NaN
# 429                          Cruella           NaN          NaN          NaN
# 430                    Jungle Cruise           NaN          NaN          NaN
# 431            The Beatles: Get Back           NaN          NaN          NaN
#
#     Release date  imdb  metascore rotten_tomatoes  \
# 0     1937-05-19   7.2        NaN             NaN
# 1     1937-12-21   7.6       95.0             NaN
# 2     1940-02-07   7.4       99.0            100%
# 3     1940-11-13   7.8       96.0             95%
# 4     1941-06-20   6.9        NaN             67%
# ..           ...   ...        ...             ...
# 427   2020-10-15   7.0       53.0             45%
# 428   2021-03-12   NaN        NaN             NaN
# 429   2021-05-28   NaN        NaN             NaN
# 430   2021-07-30   NaN        NaN             NaN
# 431   2021-08-27   8.0        NaN             NaN
#
#                                            Directed by  \
# 0                                                  NaN
# 1    ['David Hand (supervising)', 'William Cottrell...
# 2    ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 3    ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 4    ['Alfred Werker', '(live action)', 'Hamilton L...
# ..                                                 ...
# 427                                        Pete Docter
# 428               ['Don Hall', 'Carlos López Estrada']
# 429                                    Craig Gillespie
# 430                                 Jaume Collet-Serra
# 431                                      Peter Jackson
#
#                                            Produced by  \
# 0                                                  NaN
# 1                                          Walt Disney
# 2                                          Walt Disney
# 3                    ['Walt Disney', 'Ben Sharpsteen']
# 4                                          Walt Disney
# ..                                                 ...
# 427                                        Dana Murray
# 428                ['Osnat Shurer', 'Peter Del Vecho']
# 429      ['Kristin Burr', 'Andrew Gunn', 'Marc Platt']
# 430  ['John Davis', 'John Fox', 'Beau Flynn', 'Dway...
# 431  ['Peter Jackson', 'Clare Olssen', 'Jonathan Cl...
#
#                                               Music by  \
# 0                                                  NaN
# 1    ['Frank Churchill', 'Paul Smith', 'Leigh Harli...
# 2                   ['Leigh Harline', 'Paul J. Smith']
# 3                                          See program
# 4                   ['Frank Churchill', 'Larry Morey']
# ..                                                 ...
# 427                   ['Trent Reznor', 'Atticus Ross']
# 428                                                NaN
# 429                                                NaN
# 430               ['James Newton Howard', 'Metallica']
# 431                                        The Beatles
#
#                                         Distributed by
# 0                                                  NaN
# 1                                   RKO Radio Pictures
# 2                                   RKO Radio Pictures
# 3    ['Walt Disney Productions', 'RKO Radio Pictures']
# 4                                   RKO Radio Pictures
# ..                                                 ...
# 427         ['Walt Disney Studios', 'Motion Pictures']
# 428         ['Walt Disney Studios', 'Motion Pictures']
# 429                Walt Disney Studios Motion Pictures
# 430                Walt Disney Studios Motion Pictures
# 431         ['Walt Disney Studios', 'Motion Pictures']
#
# [432 rows x 12 columns]

# %% [markdown]
# ## Merge the selected dataset

# %%
data_temp = data1_select.append(data2_select, ignore_index=True)

# drop duplicated movies by title and releasse date
data_temp.drop_duplicates(subset =['title', 'Release date'], keep = 'first', inplace = True)
data_temp
# Out:
#                                title  Running time       Budget    Box office  \
# 0            Academy Award Review of          41.0          NaN  4.547200e+01
# 1    Snow White and the Seven Dwarfs          83.0    1490000.0  4.180000e+08
# 2                          Pinocchio          88.0    2600000.0  1.640000e+08
# 3                           Fantasia         126.0    2280000.0  8.330000e+07
# 4               The Reluctant Dragon          74.0     600000.0  9.600000e+05
# ..                               ...           ...          ...           ...
# 876               The Little Mermaid           NaN          NaN           NaN
# 877                Peter Pan & Wendy           NaN          NaN           NaN
# 878                       Home Alone           NaN          NaN           NaN
# 879                           Shrunk           NaN          NaN           NaN
# 880              Night at the Museum         306.0  387000000.0  1.310000e+09
#
#     Release date  imdb  metascore rotten_tomatoes  \
# 0     1937-05-19   7.2        7.2             NaN
# 1     1937-12-21   7.6        7.6             NaN
# 2     1940-02-07   7.4        7.4            100%
# 3     1940-11-13   7.8        7.8             95%
# 4     1941-06-20   6.9        6.9             67%
# ..           ...   ...        ...             ...
# 876          NaN   7.6       88.0             93%
# 877          NaN   NaN        NaN             NaN
# 878          NaN   7.6       63.0             66%
# 879          NaN   NaN        NaN             NaN
# 880          NaN   6.4       48.0             43%
#
#                                            Directed by  \
# 0                                                  NaN
# 1    ['David Hand (supervising)', 'William Cottrell...
# 2    ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 3    ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 4    ['Alfred Werker', '(live action)', 'Hamilton L...
# ..                                                 ...
# 876                                       Rob Marshall
# 877                                       David Lowery
# 878                                          Dan Mazer
# 879                                       Joe Johnston
# 880                                         Shawn Levy
#
#                                            Produced by  \
# 0                                                  NaN
# 1                                          Walt Disney
# 2                                          Walt Disney
# 3                    ['Walt Disney', 'Ben Sharpsteen']
# 4                                          Walt Disney
# ..                                                 ...
# 876  ['Rob Marshall', 'John DeLuca', 'Marc Platt', ...
# 877                       ['Jim Whitaker', 'Joe Roth']
# 878                     ['Hutch Parker', 'Dan Wilson']
# 879               ['David Hoberman', 'Todd Lieberman']
# 880  ['Shawn Levy', 'Chris Columbus', 'Michael Barn...
#
#                                               Music by  \
# 0                                                  NaN
# 1    ['Frank Churchill', 'Paul Smith', 'Leigh Harli...
# 2                   ['Leigh Harline', 'Paul J. Smith']
# 3                                          See program
# 4                   ['Frank Churchill', 'Larry Morey']
# ..                                                 ...
# 876  ['Alan Menken (score and songs)', 'Howard Ashm...
# 877                                                NaN
# 878                                        John Debney
# 879                                                NaN
# 880                                     Alan Silvestri
#
#                                         Distributed by
# 0                                                  NaN
# 1                                   RKO Radio Pictures
# 2                                   RKO Radio Pictures
# 3    ['Walt Disney Productions', 'RKO Radio Pictures']
# 4                                   RKO Radio Pictures
# ..                                                 ...
# 876         ['Walt Disney Studios', 'Motion Pictures']
# 877                Walt Disney Studios Motion Pictures
# 878                                            Disney+
# 879         ['Walt Disney Studios', 'Motion Pictures']
# 880                ['20th Century Studios', 'Disney+']
#
# [473 rows x 12 columns]

# %%
data_temp_2 = data_temp.append(data4_select, ignore_index=True)

# drop duplicated movies by title and releasse date
data_temp_2.drop_duplicates(subset =['title', 'Release date'], keep = 'first', inplace = True)
data_temp_2
# Out:
#                                title  Running time       Budget    Box office  \
# 0            Academy Award Review of          41.0          NaN  4.547200e+01
# 1    Snow White and the Seven Dwarfs          83.0    1490000.0  4.180000e+08
# 2                          Pinocchio          88.0    2600000.0  1.640000e+08
# 3                           Fantasia         126.0    2280000.0  8.330000e+07
# 4               The Reluctant Dragon          74.0     600000.0  9.600000e+05
# ..                               ...           ...          ...           ...
# 471                           Shrunk           NaN          NaN           NaN
# 472              Night at the Museum         306.0  387000000.0  1.310000e+09
# 761                     Glory Road's         106.0   30000000.0  4.290000e+07
# 784          Beverly Hills Chihuahua          91.0   20000000.0  1.493000e+08
# 900                             Soul           NaN  150000000.0           NaN
#
#     Release date  imdb  metascore rotten_tomatoes  \
# 0     1937-05-19   7.2        7.2             NaN
# 1     1937-12-21   7.6        7.6             NaN
# 2     1940-02-07   7.4        7.4            100%
# 3     1940-11-13   7.8        7.8             95%
# 4     1941-06-20   6.9        6.9             67%
# ..           ...   ...        ...             ...
# 471          NaN   NaN        NaN             NaN
# 472          NaN   6.4       48.0             43%
# 761   2006-01-13   NaN        NaN             NaN
# 784   2008-09-26   3.8       41.0             40%
# 900   2020-10-15   7.0       53.0             45%
#
#                                            Directed by  \
# 0                                                  NaN
# 1    ['David Hand (supervising)', 'William Cottrell...
# 2    ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 3    ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 4    ['Alfred Werker', '(live action)', 'Hamilton L...
# ..                                                 ...
# 471                                       Joe Johnston
# 472                                         Shawn Levy
# 761                                      James Gartner
# 784                                       Raja Gosnell
# 900                                        Pete Docter
#
#                                            Produced by  \
# 0                                                  NaN
# 1                                          Walt Disney
# 2                                          Walt Disney
# 3                    ['Walt Disney', 'Ben Sharpsteen']
# 4                                          Walt Disney
# ..                                                 ...
# 471               ['David Hoberman', 'Todd Lieberman']
# 472  ['Shawn Levy', 'Chris Columbus', 'Michael Barn...
# 761                              ['Jerry Bruckheimer']
# 784  ['David Hoberman', 'Todd Lieberman', 'John Jac...
# 900                                        Dana Murray
#
#                                               Music by  \
# 0                                                  NaN
# 1    ['Frank Churchill', 'Paul Smith', 'Leigh Harli...
# 2                   ['Leigh Harline', 'Paul J. Smith']
# 3                                          See program
# 4                   ['Frank Churchill', 'Larry Morey']
# ..                                                 ...
# 471                                                NaN
# 472                                     Alan Silvestri
# 761                                       Trevor Rabin
# 784                                     Heitor Pereira
# 900                   ['Trent Reznor', 'Atticus Ross']
#
#                                         Distributed by
# 0                                                  NaN
# 1                                   RKO Radio Pictures
# 2                                   RKO Radio Pictures
# 3    ['Walt Disney Productions', 'RKO Radio Pictures']
# 4                                   RKO Radio Pictures
# ..                                                 ...
# 471         ['Walt Disney Studios', 'Motion Pictures']
# 472                ['20th Century Studios', 'Disney+']
# 761                               Buena Vista Pictures
# 784         ['Walt Disney Studios', 'Motion Pictures']
# 900         ['Walt Disney Studios', 'Motion Pictures']
#
# [476 rows x 12 columns]

# %%
# merge above dataset with data3
data = pd.merge(data_temp_2, data3_select,  how='left', left_on=['title','Release date'], right_on = ['title','Release date'])
data
# Out:
#                                title  Running time       Budget    Box office  \
# 0            Academy Award Review of          41.0          NaN  4.547200e+01
# 1    Snow White and the Seven Dwarfs          83.0    1490000.0  4.180000e+08
# 2                          Pinocchio          88.0    2600000.0  1.640000e+08
# 3                           Fantasia         126.0    2280000.0  8.330000e+07
# 4               The Reluctant Dragon          74.0     600000.0  9.600000e+05
# ..                               ...           ...          ...           ...
# 471                           Shrunk           NaN          NaN           NaN
# 472              Night at the Museum         306.0  387000000.0  1.310000e+09
# 473                     Glory Road's         106.0   30000000.0  4.290000e+07
# 474          Beverly Hills Chihuahua          91.0   20000000.0  1.493000e+08
# 475                             Soul           NaN  150000000.0           NaN
#
#     Release date  imdb  metascore rotten_tomatoes  \
# 0     1937-05-19   7.2        7.2             NaN
# 1     1937-12-21   7.6        7.6             NaN
# 2     1940-02-07   7.4        7.4            100%
# 3     1940-11-13   7.8        7.8             95%
# 4     1941-06-20   6.9        6.9             67%
# ..           ...   ...        ...             ...
# 471          NaN   NaN        NaN             NaN
# 472          NaN   6.4       48.0             43%
# 473   2006-01-13   NaN        NaN             NaN
# 474   2008-09-26   3.8       41.0             40%
# 475   2020-10-15   7.0       53.0             45%
#
#                                            Directed by  \
# 0                                                  NaN
# 1    ['David Hand (supervising)', 'William Cottrell...
# 2    ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 3    ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 4    ['Alfred Werker', '(live action)', 'Hamilton L...
# ..                                                 ...
# 471                                       Joe Johnston
# 472                                         Shawn Levy
# 473                                      James Gartner
# 474                                       Raja Gosnell
# 475                                        Pete Docter
#
#                                            Produced by  \
# 0                                                  NaN
# 1                                          Walt Disney
# 2                                          Walt Disney
# 3                    ['Walt Disney', 'Ben Sharpsteen']
# 4                                          Walt Disney
# ..                                                 ...
# 471               ['David Hoberman', 'Todd Lieberman']
# 472  ['Shawn Levy', 'Chris Columbus', 'Michael Barn...
# 473                              ['Jerry Bruckheimer']
# 474  ['David Hoberman', 'Todd Lieberman', 'John Jac...
# 475                                        Dana Murray
#
#                                               Music by  \
# 0                                                  NaN
# 1    ['Frank Churchill', 'Paul Smith', 'Leigh Harli...
# 2                   ['Leigh Harline', 'Paul J. Smith']
# 3                                          See program
# 4                   ['Frank Churchill', 'Larry Morey']
# ..                                                 ...
# 471                                                NaN
# 472                                     Alan Silvestri
# 473                                       Trevor Rabin
# 474                                     Heitor Pereira
# 475                   ['Trent Reznor', 'Atticus Ross']
#
#                                         Distributed by    genre  \
# 0                                                  NaN      NaN
# 1                                   RKO Radio Pictures  Musical
# 2                                   RKO Radio Pictures      NaN
# 3    ['Walt Disney Productions', 'RKO Radio Pictures']  Musical
# 4                                   RKO Radio Pictures      NaN
# ..                                                 ...      ...
# 471         ['Walt Disney Studios', 'Motion Pictures']      NaN
# 472                ['20th Century Studios', 'Disney+']      NaN
# 473                               Buena Vista Pictures      NaN
# 474         ['Walt Disney Studios', 'Motion Pictures']      NaN
# 475         ['Walt Disney Studios', 'Motion Pictures']      NaN
#
#      inflation_adjusted_gross
# 0                         NaN
# 1                5.228953e+09
# 2                         NaN
# 3                2.187091e+09
# 4                         NaN
# ..                        ...
# 471                       NaN
# 472                       NaN
# 473                       NaN
# 474                       NaN
# 475                       NaN
#
# [476 rows x 14 columns]

# %%
# count null value for each column
data.isnull().sum(axis = 0)
# Out:
# title                         0
# Running time                 18
# Budget                      186
# Box office                  104
# Release date                 29
# imdb                         26
# metascore                    41
# rotten_tomatoes              59
# Directed by                   1
# Produced by                  12
# Music by                     12
# Distributed by                3
# genre                       342
# inflation_adjusted_gross    339
# dtype: int64
